# %% [markdown]
# # Claudia Pinzón
#
# ## Taller # 4: Pre-Procesamiento de textos y Featuring Engineering

# %%
import re
from collections import Counter

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')

from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Punto 1: Pre-Procesamiento
#
# - `[5 pts]` Leer el archivo `dialogos.csv` usando `pandas`
# - `[10 pts]` Crear una nueva columna con el texto en minúscula, sin caracteres especiales ni números y sin palabras vacias
# - `[7 pts]` Usando la nueva columna, ¿cuáles son las 10 palabras más usadas?

# %%
#Carga del archivo
import pandas as pd
df1 = pd.read_csv("../Claus/NLP/dialogos.csv")
print(df1)
# Out:
#                                               Locución
# 0                                       Francamente no
# 1    Lo del canadiense. Por favor, como que vosotro...
# 2    Tienes razón. A lo mejor así te liberas de tu ...
# 3                                      Pues, tú sabrás
# 4                              Para mí que fue Krieger
# ..                                                 ...
# 954                        Yo qué sé, digo yo qué será
# 955  Lo han entendido mal. Las joyas que venden en ...
# 956                            Oooo... Me llamo Vivian
# 957                  ¿De dónde? ¿Del coño de tu madre?
# 958                       Ah, sí esto podría funcionar
#
# [959 rows x 1 columns]

# %%
#Convertir
df2= pd.DataFrame(data=df1)
df2
df2 = df2.to_string()
print(df2)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Locución
# ...

# %%
import re
import unicodedata
from unicodedata import normalize
from nltk.corpus import stopwords

# %%
# 2. Pasar a minúscula, quitar números, caracteres especiales y palabras vacías
trans_tab = dict.fromkeys(map(ord, u'\u0301\u0308'), None)
df2 = normalize('NFKC', normalize('NFKD', df2).translate(trans_tab))

Caracteres = 'áéíóú"''¡¿?$@#&)=;(/,.:!%1234567890'
for cambio in Caracteres:
            df2 = df2.replace(cambio, '')

df2 = df2.lower()
df2 = df2.strip()
df2 = df2.split()

stopwords_sp = stopwords.words('spanish')
df2 = [palabra for palabra in df2 if palabra not in stopwords_sp]
df2
# Out:
# ['locucion',
#  'francamente',
#  'canadiense',
#  'favor',
#  'tirariais',
#  'alli',
#  'si',
#  'pudieseis',
#  'razon',
#  'mejor',
#  'asi',
#  'liberas',
#  'energia',
#  'nagativa',
#  'pues',
#  'sabras',
#  'krieger',
#  'bebe',
#  'lando',
#  'serio',
#  'randy',
#  'creo',
#  'deporte',
#  'hizo',
#  'daño',
#  'cerebro',
#  'estate',
#  'quieto',
#  'esperad',
#  'parecido',
#  'archer',
#  'asustado',
#  'usted',
#  'jode',
#  'carajo',
#  'dios',
#  'pibe',
#  'oigo',
#  'claro',
#  'fuma',
#  'junto',
#  'niña',
#  'decir',
#  'robotizado',
#  'coño',
#  'sacado',
#  'mano',
#  'bionica',
#  'pues',
#  'venga',
#  'subid',
#  'atras',
#  'avion',
#  'esperando',
#  'recordadme',
#  'si',
#  'desgraciado',
#  'mata',
#  'haga',
#  'jodas',
#  'cyril',
#  'haces',
#  'ventana',
#  'pues',
#  'existe',
#  'refran',
#  'hindu',
#  'dice',
#  'fundio',
#  'genero',
#  'corten',
#  'perdon',
#  'voy',
#  'nuevo',
#  'intento',
#  'decir',
#  'deberiamos',
#  'tener',
# ...

# %%
dfString = ', '.join(df2)

# %%
import collections

counter = collections.Counter(dfString.split())
for palabra, cont in counter.most_common():
    print(f"'{palabra}' aparece {cont} {'veces' if cont > 1 else 'vez'}.")
# Out:
# 'si,' aparece 132 veces.
# 'bien,' aparece 36 veces.
# 'asi,' aparece 30 veces.
# 'mas,' aparece 29 veces.
# 'oh,' aparece 28 veces.
# 'aqui,' aparece 26 veces.
# 'vamos,' aparece 26 veces.
# 'sarcasmobol,' aparece 24 veces.
# 'bueno,' aparece 24 veces.
# 'solo,' aparece 23 veces.
# 'lana,' aparece 22 veces.
# 'juego,' aparece 21 veces.
# 'ahora,' aparece 20 veces.
# 'butters,' aparece 20 veces.
# 'vale,' aparece 19 veces.
# 'pues,' aparece 18 veces.
# 'archer,' aparece 17 veces.
# 'voy,' aparece 17 veces.
# 'oro,' aparece 17 veces.
# 'dos,' aparece 17 veces.
# 'hecho,' aparece 17 veces.
# 'ver,' aparece 16 veces.
# 'claro,' aparece 15 veces.
# 'ser,' aparece 15 veces.
# 'papa,' aparece 15 veces.
# 'eh,' aparece 15 veces.
# 'seguro,' aparece 15 veces.
# 'aj,' aparece 15 veces.
# 'serio,' aparece 14 veces.
# 'creo,' aparece 14 veces.
# 'oye,' aparece 14 veces.
# 'gracias,' aparece 14 veces.
# 'verdad,' aparece 14 veces.
# 'quiero,' aparece 14 veces.
# 'mejor,' aparece 13 veces.
# ...

# %% [markdown]
# # Punto 2: Representación vectorial
#
# - `[15 pts]` Crear una bolsa de palabras (BoW) del corpus usando la columna pre-procesada (Usando la función de `sklearn`)
# - `[10 pts]` ¿Cuántas palabras hay en el vocabulario? (Usando la función de `sklearn`)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# crear la transformación
palabras = [dfString]
vectorizar = CountVectorizer()

# tokenizar y construir el vocabulario
vectorizar.fit(palabras)

print(vectorizar.vocabulary_)
# Out:
# {'locucion': 1172, 'francamente': 818, 'canadiense': 278, 'favor': 798, 'tirariais': 1940, 'alli': 62, 'si': 1814, 'pudieseis': 1592, 'razon': 1651, 'mejor': 1229, 'asi': 126, 'liberas': 1110, 'energia': 688, 'nagativa': 1302, 'pues': 1600, 'sabras': 1736, 'krieger': 1086, 'bebe': 182, 'lando': 1095, 'serio': 1801, 'randy': 1646, 'creo': 481, 'deporte': 573, 'hizo': 953, 'daño': 532, 'cerebro': 318, 'estate': 758, 'quieto': 1634, 'esperad': 739, 'parecido': 1425, 'archer': 110, 'asustado': 132, 'usted': 2005, 'jode': 1046, 'carajo': 293, 'dios': 621, 'pibe': 1492, 'oigo': 1380, 'claro': 353, 'fuma': 831, 'junto': 1075, 'niña': 1329, 'decir': 547, 'robotizado': 1716, 'coño': 462, 'sacado': 1739, 'mano': 1202, 'bionica': 199, 'venga': 2038, 'subid': 1869, 'atras': 139, 'avion': 151, 'esperando': 741, 'recordadme': 1662, 'desgraciado': 588, 'mata': 1215, 'haga': 924, 'jodas': 1045, 'cyril': 517, 'haces': 921, 'ventana': 2044, 'existe': 776, 'refran': 1675, 'hindu': 952, 'dice': 606, 'fu
# ...

# %%
# codificador
vector = vectorizar.transform(palabras)
print(vector.shape)
# Out:
# (1, 2105)

# %% [markdown]
# # Punto 3: 🤔
#
# - `[3pts]` ¿Cuándo es una mejor idea usar una bolsa de n-gramas en vez de una bolsa de palabras?

# %% [markdown]
# Cuando tengo datos geográficos, procesamiento de textos normativos (leyes, códigos, decretos, CONPES), traducciones

# %% [markdown]
# # BONUS Punto 4: 😜
#
# - `[2pt]` ¿A qué pertenecen los dialogos de ese archivo?

# %% [markdown]
# South park, capítulo sarcasmoball
