# %% [markdown]
# 1. Pre-procesamiento

# %%
import re
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')

from nltk.stem.snowball import SnowballStemmer
spanishStemmer=SnowballStemmer("spanish")

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_distances

# %%
# Leer archivo

doc = pd.read_csv("C:/Users/eliza/OneDrive/Desktop/Claus/Konrad/NLP/bob_esponja.csv")
doc
# Out:
#                           Personaje  \
# 0  Bob Esponja Pantalones Cuadrados
# 1                 Patricio Estrella
# 2              Calamardo Tentáculos
# 3                  Arenita Mejillas
# 4               Eugenio H. Cangrejo
# 5               Sheldon J. Plankton
# 6                    Karen Plankton
# 7                  Perlita Cangrejo
# 8                         Sra. Puff
# 9                   Gary el Caracol
#
#                                          Descripción
# 0  Bob Esponja es una esponja de mar con forma re...
# 1  Es una estrella de mar de color rosa, el mejor...
# 2  Calamardo Tentáculos es un personaje principal...
# 3  Arenita Mejillas (Sandy Cheeks en inglés) en u...
# 4  Don Eugenio H. Cangrejo (normalmente llamado S...
# 5  Sheldon J. Plankton, o simplemente Plankton, e...
# 6  Karen Plankton es uno de los dos principales a...
# 7  Perla "Perlita" Cangrejo es un personaje princ...
# 8  La Señora Puff es un personaje principal de Bo...
# 9  Gary el Caracol es un personaje principal de B...

# %%
#Nueva columna con modificaciones

def pre_procesado(texto):
    texto = texto.lower()                                                         #pasar a minúsculas
    texto = re.sub(r"[\W\d_´]+", " ", texto)                                      #eliminar caracteres
    texto = [palabra for palabra in texto.split() if palabra not in stopwords_sp] #quitar palabras vacías
    texto = [spanishStemmer.stem(texto) for texto in texto]                       #stemming de las palabras
    texto = [texto.lower() for texto in texto if len(texto) > 2 and texto.isalpha()] #quitar palabras de menos de 2 caracteres
    texto = " ".join(texto)
    return (texto)

doc['pre_procesado']=doc['Descripción'].apply(lambda texto: pre_procesado(texto))
doc
# Out:
#                           Personaje  \
# 0  Bob Esponja Pantalones Cuadrados
# 1                 Patricio Estrella
# 2              Calamardo Tentáculos
# 3                  Arenita Mejillas
# 4               Eugenio H. Cangrejo
# 5               Sheldon J. Plankton
# 6                    Karen Plankton
# 7                  Perlita Cangrejo
# 8                         Sra. Puff
# 9                   Gary el Caracol
#
#                                          Descripción  \
# 0  Bob Esponja es una esponja de mar con forma re...
# 1  Es una estrella de mar de color rosa, el mejor...
# 2  Calamardo Tentáculos es un personaje principal...
# 3  Arenita Mejillas (Sandy Cheeks en inglés) en u...
# 4  Don Eugenio H. Cangrejo (normalmente llamado S...
# 5  Sheldon J. Plankton, o simplemente Plankton, e...
# 6  Karen Plankton es uno de los dos principales a...
# 7  Perla "Perlita" Cangrejo es un personaje princ...
# 8  La Señora Puff es un personaje principal de Bo...
# 9  Gary el Caracol es un personaje principal de B...
#
#                                        pre_procesado
# 0  bob esponj esponj mar form rectangul color ama...
# 1  estrell mar color ros mejor amig bob esponj ju...
# 2  calamard tentacul personaj principal bob espon...
# 3  arenit mejill sandy cheeks ingles personaj pri...
# 4  don eugeni cangrej normal llam señor cangrej e...
# 5  sheldon plankton simplement plankton dos antag...
# 6  kar plankton dos principal antagon bob esponj ...
# 7  perl perlit cangrej personaj principal bob esp...
# 8  señor puff personaj principal bob esponj maest...
# 9  gary caracol personaj principal bob esponj que...

# %% [markdown]
# 2. Matriz TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer()
tfidf = tfidf_vect.fit_transform(doc['pre_procesado'].values)

tfidf_matrix = pd.DataFrame(tfidf.toarray(), columns=tfidf_vect.get_feature_names())
tfidf_matrix.index = doc.index

tfidf_matrix = tfidf_matrix.T.round(3)
tfidf_matrix.columns = doc.Personaje.values
tfidf_matrix
# Out:
#           Bob Esponja Pantalones Cuadrados  Patricio Estrella  \
# abaj                                 0.058               0.00
# aborrec                              0.000               0.00
# acab                                 0.000               0.00
# accident                             0.049               0.00
# acept                                0.000               0.00
# ...                                    ...                ...
# viv                                  0.000               0.05
# vol                                  0.058               0.00
# voz                                  0.197               0.00
# vuelv                                0.173               0.00
# zapat                                0.043               0.00
#
#           Calamardo Tentáculos  Arenita Mejillas  Eugenio H. Cangrejo  \
# abaj                     0.000             0.000                0.000
# aborrec                  0.091             0.000                0.000
# acab                     0.091             0.000                0.000
# accident                 0.000             0.000                0.045
# acept                    0.000             0.000                0.000
# ...                        ...               ...                  ...
# viv                      0.060             0.108                0.070
# vol                      0.000             0.000                0.000
# voz                      0.000             0.139                0.000
# vuelv                    0.000             0.000                0.000
# zapat                    0.000             0.000                0.000
#
#           Sheldon J. Plankton  Karen Plankton  Perlita Cangrejo  Sra. Puff  \
# abaj                      0.0           0.000               0.0      0.000
# aborrec                   0.0           0.000               0.0      0.000
# acab                      0.0           0.000               0.0      0.000
# accident                  0.0           0.000               0.0      0.000
# acept                     0.0           0.064               0.0      0.000
# ...                       ...             ...               ...        ...
# viv                       0.0           0.000               0.0      0.000
# vol                       0.0           0.000               0.0      0.000
# voz                       0.0           0.000               0.0      0.000
# vuelv                     0.0           0.000               0.0      0.000
# zapat                     0.0           0.000               0.0      0.093
#
#           Gary el Caracol
# abaj                0.000
# aborrec             0.000
# acab                0.000
# accident            0.000
# acept               0.000
# ...                   ...
# viv                 0.000
# vol                 0.000
# voz                 0.000
# vuelv               0.000
# zapat               0.068
#
# [702 rows x 10 columns]

# %% [markdown]
# 3. Medidas de Similitud

# %%
# distancia del coseno entre personajes
from sklearn.metrics.pairwise import cosine_distances

dist_cos = cosine_distances(tfidf_matrix.T.values)
dist_cos = pd.DataFrame(dist_cos, columns = tfidf_matrix.columns, index = tfidf_matrix.columns)
dist_cos
# Out:
#                                   Bob Esponja Pantalones Cuadrados  \
# Bob Esponja Pantalones Cuadrados                          0.000000
# Patricio Estrella                                         0.831677
# Calamardo Tentáculos                                      0.918198
# Arenita Mejillas                                          0.836849
# Eugenio H. Cangrejo                                       0.867014
# Sheldon J. Plankton                                       0.882350
# Karen Plankton                                            0.938282
# Perlita Cangrejo                                          0.884641
# Sra. Puff                                                 0.856903
# Gary el Caracol                                           0.923351
#
#                                   Patricio Estrella  Calamardo Tentáculos  \
# Bob Esponja Pantalones Cuadrados           0.831677              0.918198
# Patricio Estrella                          0.000000              0.790027
# Calamardo Tentáculos                       0.790027              0.000000
# Arenita Mejillas                           0.840653              0.919676
# Eugenio H. Cangrejo                        0.830567              0.830830
# Sheldon J. Plankton                        0.971415              0.916760
# Karen Plankton                             0.929954              0.949913
# Perlita Cangrejo                           0.891130              0.967253
# Sra. Puff                                  0.952511              0.968111
# Gary el Caracol                            0.894189              0.851343
#
#                                   Arenita Mejillas  Eugenio H. Cangrejo  \
# Bob Esponja Pantalones Cuadrados          0.836849             0.867014
# Patricio Estrella                         0.840653             0.830567
# Calamardo Tentáculos                      0.919676             0.830830
# Arenita Mejillas                          0.000000             0.907361
# Eugenio H. Cangrejo                       0.907361             0.000000
# Sheldon J. Plankton                       0.967271             0.688275
# Karen Plankton                            0.948252             0.891333
# Perlita Cangrejo                          0.961946             0.797920
# Sra. Puff                                 0.972006             0.895439
# Gary el Caracol                           0.900317             0.920153
#
#                                   Sheldon J. Plankton  Karen Plankton  \
# Bob Esponja Pantalones Cuadrados             0.882350        0.938282
# Patricio Estrella                            0.971415        0.929954
# Calamardo Tentáculos                         0.916760        0.949913
# Arenita Mejillas                             0.967271        0.948252
# Eugenio H. Cangrejo                          0.688275        0.891333
# Sheldon J. Plankton                          0.000000        0.792585
# Karen Plankton                               0.792585        0.000000
# Perlita Cangrejo                             0.921823        0.966145
# Sra. Puff                                    0.986654        0.984919
# Gary el Caracol                              0.968991        0.965109
#
#                                   Perlita Cangrejo  Sra. Puff  Gary el Caracol
# Bob Esponja Pantalones Cuadrados          0.884641   0.856903         0.923351
# Patricio Estrella                         0.891130   0.952511         0.894189
# Calamardo Tentáculos                      0.967253   0.968111         0.851343
# Arenita Mejillas                          0.961946   0.972006         0.900317
# Eugenio H. Cangrejo                       0.797920   0.895439         0.920153
# Sheldon J. Plankton                       0.921823   0.986654         0.968991
# Karen Plankton                            0.966145   0.984919         0.965109
# Perlita Cangrejo                          0.000000   0.873508         0.969351
# Sra. Puff                                 0.873508   0.000000         0.964104
# Gary el Caracol                           0.969351   0.964104         0.000000

# %%
def color_red(val):
    color = 'green' if val ==True else 'red'
    return f'color: {color}'
    
t = dist_cos>0.95
t.style.applymap(color_red)
# Out:
# <style  type="text/css" >
# #T_b150d_row0_col0,#T_b150d_row0_col1,#T_b150d_row0_col2,#T_b150d_row0_col3,#T_b150d_row0_col4,#T_b150d_row0_col5,#T_b150d_row0_col6,#T_b150d_row0_col7,#T_b150d_row0_col8,#T_b150d_row0_col9,#T_b150d_row1_col0,#T_b150d_row1_col1,#T_b150d_row1_col2,#T_b150d_row1_col3,#T_b150d_row1_col4,#T_b150d_row1_col6,#T_b150d_row1_col7,#T_b150d_row1_col9,#T_b150d_row2_col0,#T_b150d_row2_col1,#T_b150d_row2_col2,#T_b150d_row2_col3,#T_b150d_row2_col4,#T_b150d_row2_col5,#T_b150d_row2_col6,#T_b150d_row2_col9,#T_b150d_row3_col0,#T_b150d_row3_col1,#T_b150d_row3_col2,#T_b150d_row3_col3,#T_b150d_row3_col4,#T_b150d_row3_col6,#T_b150d_row3_col9,#T_b150d_row4_col0,#T_b150d_row4_col1,#T_b150d_row4_col2,#T_b150d_row4_col3,#T_b150d_row4_col4,#T_b150d_row4_col5,#T_b150d_row4_col6,#T_b150d_row4_col7,#T_b150d_row4_col8,#T_b150d_row4_col9,#T_b150d_row5_col0,#T_b150d_row5_col2,#T_b150d_row5_col4,#T_b150d_row5_col5,#T_b150d_row5_col6,#T_b150d_row5_col7,#T_b150d_row6_col0,#T_b150d_row6_col1,#T_b150d_row6_col2,#T_b150d_row6_col3,#T_b150d_row6_col4,#T_b150d_row6_col5,#T_b150d_row6_col6,#T_b150d_row7_col0,#T_b150d_row7_col1,#T_b150d_row7_col4,#T_b150d_row7_col5,#T_b150d_row7_col7,#T_b150d_row7_col8,#T_b150d_row8_col0,#T_b150d_row8_col4,#T_b150d_row8_col7,#T_b150d_row8_col8,#T_b150d_row9_col0,#T_b150d_row9_col1,#T_b150d_row9_col2,#T_b150d_row9_col3,#T_b150d_row9_col4,#T_b150d_row9_col9{
#             color:  red;
#         }#T_b150d_row1_col5,#T_b150d_row1_col8,#T_b150d_row2_col7,#T_b150d_row2_col8,#T_b150d_row3_col5,#T_b150d_row3_col7,#T_b150d_row3_col8,#T_b150d_row5_col1,#T_b150d_row5_col3,#T_b150d_row5_col8,#T_b150d_row5_col9,#T_b150d_row6_col7,#T_b150d_row6_col8,#T_b150d_row6_col9,#T_b150d_row7_col2,#T_b150d_row7_col3,#T_b150d_row7_col6,#T_b150d_row7_col9,#T_b150d_row8_col1,#T_b150d_row8_col2,#T_b150d_row8_col3,#T_b150d_row8_col5,#T_b150d_row8_col6,#T_b150d_row8_col9,#T_b150d_row9_col5,#T_b150d_row9_col6,#T_b150d_row9_col7,#T_b150d_row9_col8{
#             color:  green;
#         }</style><table id="T_b150d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Bob Esponja Pantalones Cuadrados</th>        <th class="col_heading level0 col1" >Patricio Estrella</th>        <th class="col_heading level0 col2" >Calamardo Tentáculos</th>        <th class="col_heading level0 col3" >Arenita Mejillas</th>        <th class="col_heading level0 col4" >Eugenio H. Cangrejo</th>        <th class="col_heading level0 col5" >Sheldon J. Plankton</th>        <th class="col_heading level0 col6" >Karen Plankton</th>        <th class="col_heading level0 col7" >Perlita Cangrejo</th>        <th class="col_heading level0 col8" >Sra. Puff</th>        <th class="col_heading level0 col9" >Gary el Caracol</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b150d_level0_row0" class="row_heading level0 row0" >Bob Esponja Pantalones Cuadrados</th>
#                         <td id="T_b150d_row0_col0" class="data row0 col0" >False</td>
#                         <td id="T_b150d_row0_col1" class="data row0 col1" >False</td>
#                         <td id="T_b150d_row0_col2" class="data row0 col2" >False</td>
#                         <td id="T_b150d_row0_col3" class="data row0 col3" >False</td>
#                         <td id="T_b150d_row0_col4" class="data row0 col4" >False</td>
#                         <td id="T_b150d_row0_col5" class="data row0 col5" >False</td>
#                         <td id="T_b150d_row0_col6" class="data row0 col6" >False</td>
#                         <td id="T_b150d_row0_col7" class="data row0 col7" >False</td>
#                         <td id="T_b150d_row0_col8" class="data row0 col8" >False</td>
#                         <td id="T_b150d_row0_col9" class="data row0 col9" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b150d_level0_row1" class="row_heading level0 row1" >Patricio Estrella</th>
#                         <td id="T_b150d_row1_col0" class="data row1 col0" >False</td>
#                         <td id="T_b150d_row1_col1" class="data row1 col1" >False</td>
#                         <td id="T_b150d_row1_col2" class="data row1 col2" >False</td>
#                         <td id="T_b150d_row1_col3" class="data row1 col3" >False</td>
#                         <td id="T_b150d_row1_col4" class="data row1 col4" >False</td>
#                         <td id="T_b150d_row1_col5" class="data row1 col5" >True</td>
#                         <td id="T_b150d_row1_col6" class="data row1 col6" >False</td>
#                         <td id="T_b150d_row1_col7" class="data row1 col7" >False</td>
#                         <td id="T_b150d_row1_col8" class="data row1 col8" >True</td>
#                         <td id="T_b150d_row1_col9" class="data row1 col9" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b150d_level0_row2" class="row_heading level0 row2" >Calamardo Tentáculos</th>
#                         <td id="T_b150d_row2_col0" class="data row2 col0" >False</td>
#                         <td id="T_b150d_row2_col1" class="data row2 col1" >False</td>
#                         <td id="T_b150d_row2_col2" class="data row2 col2" >False</td>
#                         <td id="T_b150d_row2_col3" class="data row2 col3" >False</td>
#                         <td id="T_b150d_row2_col4" class="data row2 col4" >False</td>
#                         <td id="T_b150d_row2_col5" class="data row2 col5" >False</td>
#                         <td id="T_b150d_row2_col6" class="data row2 col6" >False</td>
#                         <td id="T_b150d_row2_col7" class="data row2 col7" >True</td>
#                         <td id="T_b150d_row2_col8" class="data row2 col8" >True</td>
#                         <td id="T_b150d_row2_col9" class="data row2 col9" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b150d_level0_row3" class="row_heading level0 row3" >Arenita Mejillas</th>
#                         <td id="T_b150d_row3_col0" class="data row3 col0" >False</td>
#                         <td id="T_b150d_row3_col1" class="data row3 col1" >False</td>
#                         <td id="T_b150d_row3_col2" class="data row3 col2" >False</td>
#                         <td id="T_b150d_row3_col3" class="data row3 col3" >False</td>
#                         <td id="T_b150d_row3_col4" class="data row3 col4" >False</td>
#                         <td id="T_b150d_row3_col5" class="data row3 col5" >True</td>
#                         <td id="T_b150d_row3_col6" class="data row3 col6" >False</td>
#                         <td id="T_b150d_row3_col7" class="data row3 col7" >True</td>
#                         <td id="T_b150d_row3_col8" class="data row3 col8" >True</td>
#                         <td id="T_b150d_row3_col9" class="data row3 col9" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b150d_level0_row4" class="row_heading level0 row4" >Eugenio H. Cangrejo</th>
#                         <td id="T_b150d_row4_col0" class="data row4 col0" >False</td>
#                         <td id="T_b150d_row4_col1" class="data row4 col1" >False</td>
#                         <td id="T_b150d_row4_col2" class="data row4 col2" >False</td>
#                         <td id="T_b150d_row4_col3" class="data row4 col3" >False</td>
#                         <td id="T_b150d_row4_col4" class="data row4 col4" >False</td>
#                         <td id="T_b150d_row4_col5" class="data row4 col5" >False</td>
#                         <td id="T_b150d_row4_col6" class="data row4 col6" >False</td>
#                         <td id="T_b150d_row4_col7" class="data row4 col7" >False</td>
#                         <td id="T_b150d_row4_col8" class="data row4 col8" >False</td>
#                         <td id="T_b150d_row4_col9" class="data row4 col9" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b150d_level0_row5" class="row_heading level0 row5" >Sheldon J. Plankton</th>
#                         <td id="T_b150d_row5_col0" c

# %%
# Mayor similitud entre personajes

np.fill_diagonal(dist_cos.values, 999999)
resultado = round(dist_cos.min().min(),6)
resultado
# Out:
# 0.688275

# %%
sim = dist_cos.where(dist_cos==resultado).dropna(how='all').dropna(axis=1)
sim
# Out:
# Empty DataFrame
# Columns: [Bob Esponja Pantalones Cuadrados, Patricio Estrella, Calamardo Tentáculos, Arenita Mejillas, Eugenio H. Cangrejo, Sheldon J. Plankton, Karen Plankton, Perlita Cangrejo, Sra. Puff, Gary el Caracol]
# Index: []

# %%
# Mayor Diferencia entre personajes

np.fill_diagonal(dist_cos.values, -999999)
round(dist_cos.max().max(),6)
# Out:
# 0.986654

# %%
dif = dist_cos.where(dist_cos==round(dist_cos.max().max(),6)).dropna(how='all').dropna(axis=1)
dif
# Out:
# Empty DataFrame
# Columns: [Bob Esponja Pantalones Cuadrados, Patricio Estrella, Calamardo Tentáculos, Arenita Mejillas, Eugenio H. Cangrejo, Sheldon J. Plankton, Karen Plankton, Perlita Cangrejo, Sra. Puff, Gary el Caracol]
# Index: []
