# %% [markdown]
# Web Scraping de 10 animales en Wikipedia (en búcle)

# %%
#Librerías
import bs4 as bs 
import urllib.request

# %%
#pip install beautifulsoup4
#pip install lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\eliza\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\eliza\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<html><p>This is <b>invalid HTML</p></html>", "lxml")
print(soup)
# Out:
# <html><body><p>This is <b>invalid HTML</b></p></body></html>

# %%
# Encabezado de cada página

a = 'Felis_silvestris_catus'
b = 'Vultur_gryphus'
c = 'Camelus'
d = 'Aves'
e = 'Balaenidae'
f = 'Equus_ferus_caballus'
g = 'Oryctolagus_cuniculus'
h = 'Phocidae'
i = 'Crocodilia'
j = 'Ornithorhynchus_anatinus'

web_animals = [a, b, c, d, e, f, g, h, i, j]

for x in web_animals:

    enlace = ('https://es.wikipedia.org/wiki/' + x)
    soup = BeautifulSoup(urllib.request.urlopen(enlace))
    print (soup.h1.string)
# Out:
# Felis silvestris catus
# Vultur gryphus
# Camelus
# Aves
# Balaenidae
# Equus ferus caballus
# Oryctolagus cuniculus
# Phocidae
# Crocodilia
# Ornithorhynchus anatinus

# %%
# Extracción de texto en negrita dentro de cada página 

for x in web_animals:

    enlace = ('https://es.wikipedia.org/wiki/' + x)
    soup = (BeautifulSoup(urllib.request.urlopen(enlace)))
    
    title = (soup.select('p')[0].text.strip())
    
    for x in range(11):
        w = ((soup.find_all('b')[x + 0]).getText())
        print (w)
    
    print(w)
    w = ''
# Out:
# F. s. catus
# gato doméstico
# Felis silvestris catus
# gato
# minino
# michino
# michi
# micho
# mizo
# miz
# morroño
# morroño
# Vultur
# Vultur gryphus
# cóndor andino
# cóndor de los Cerros
# cóndor de los Andes
# cóndor
# Vultur gryphus
# El cóndor pasa…
# El cóndor herido
# Condor Mallku
# Condorito
# Condorito
# Camelus
# Camelus
# camellos
# dromedarios
# Registro Fósil
# Localidad
# País
# Época
# Especies
# II
# 15
# 15
# Aves
# aves
# Aves
# Aves
# Aves
# Subclase Neornithes
# 11
# a
# b
# c
# d
# d
# Balaenidae
# balénidos
# Balaenidae
# ballena
# Género
# Especie
# Nombre común
# a
# b
# Balaenidae
# Balaenidae
# Balaenidae
# E. f. caballus
# caballo
# Equus ferus caballus
# yegua
# potros
# potrillos
# potras
# potrancas
# Alazán
# Albino
# Bayo
# Bayo
# O. cuniculus
# conejo común
# conejo europeo
# Oryctolagus cuniculus
# cunicultura
# producción cunícola
# Holandés enano
# Belier Enano
# Mini Lop
# Teddy Dwerg:
# Teddy Lop:
# Teddy Lop:
# Phocidae
# fócidos
# focas verdaderas
# Phocidae
# Familia Phocidae
# Subfamilia Monachinae
# Tribu Monachini
# Tribu Miroungini
# Tribu Lobodontini
# Subfamilia Phocinae
# Tribu Phocini
# Tribu Phocini
# Crocodilia
# crocodilios
# Crocodilia
# cocodrilos
# gaviales
# aligátores
# caimanes
# Crocodilia
# Crocodilia
# a
# b
# b
# O. anatinus
# ornitorrinco
# Ornithorhynchus anatinus
# Dimensiones promedio
# a
# b
# c
# d
# e
# a
# b
# b

# %% [markdown]
# Reemplazar todas las tíldes del texto extraído anteriormente por un asterisco

# %%
# Librerías

import re
import unicodedata
from unicodedata import normalize

# %%
# Modificación de caracteres

Caracteres = 'áéíóú'

for x in web_animals:

    enlace = ('https://es.wikipedia.org/wiki/' + x)
    soup = BeautifulSoup(urllib.request.urlopen(enlace))
    title = soup.select('p')[0].text.strip()

    for x in range(11):
        Lista_animales = ((soup.find_all('b')[x + 0]).getText())
        
        for cambio in Caracteres:
            Lista_animales = Lista_animales.replace(cambio, '*')
    
        print(Lista_animales)
# Out:
# F. s. catus
# gato dom*stico
# Felis silvestris catus
# gato
# minino
# michino
# michi
# micho
# mizo
# miz
# morroño
# Vultur
# Vultur gryphus
# c*ndor andino
# c*ndor de los Cerros
# c*ndor de los Andes
# c*ndor
# Vultur gryphus
# El c*ndor pasa…
# El c*ndor herido
# Condor Mallku
# Condorito
# Camelus
# Camelus
# camellos
# dromedarios
# Registro F*sil
# Localidad
# Pa*s
# Época
# Especies
# II
# 15
# Aves
# aves
# Aves
# Aves
# Aves
# Subclase Neornithes
# 11
# a
# b
# c
# d
# Balaenidae
# bal*nidos
# Balaenidae
# ballena
# G*nero
# Especie
# Nombre com*n
# a
# b
# Balaenidae
# Balaenidae
# E. f. caballus
# caballo
# Equus ferus caballus
# yegua
# potros
# potrillos
# potras
# potrancas
# Alaz*n
# Albino
# Bayo
# O. cuniculus
# conejo com*n
# conejo europeo
# Oryctolagus cuniculus
# cunicultura
# producci*n cun*cola
# Holand*s enano
# Belier Enano
# Mini Lop
# Teddy Dwerg:
# Teddy Lop:
# Phocidae
# f*cidos
# focas verdaderas
# Phocidae
# Familia Phocidae
# Subfamilia Monachinae
# Tribu Monachini
# Tribu Miroungini
# Tribu Lobodontini
# Subfamilia Phocinae
# Tribu Phocini
# Crocodilia
# crocodilios
# Crocodilia
# cocodrilos
# gaviales
# alig*tores
# caimanes
# Crocodilia
# Crocodilia
# a
# b
# O. anatinus
# ornitorrinco
# Ornithorhynchus anatinus
# Dimensiones promedio
# a
# b
# c
# d
# e
# a
# b

# %%
#Nota: La primera parte de este notebook se realizó con la colaboración de Jhon Rubiano
